# %%
import os
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import pandas as pd
from datetime import datetime
from statsmodels.tsa.stattools import acf, pacf, adfuller, kpss, coint, grangercausalitytests
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
import matplotlib

# %%
FIRST_SLICE_DATE: datetime = datetime.strptime('27/10/2018', '%d/%m/%Y')
SECOND_SLICE_DATE: datetime = datetime.strptime('1/5/2020', '%d/%m/%Y')

# %%
def transform_date_series(df: pd.DataFrame, date_key: str) -> pd.DataFrame:
    dff: pd.DataFrame = df.copy()
    dff.loc[:, date_key] = pd.to_datetime(dff.loc[:, date_key], unit='s')
    
    return dff.set_index(date_key)

# %%
def filter_series(df: pd.DataFrame, slice1: datetime, slice2: datetime) -> pd.DataFrame:
    dff: pd.DataFrame = df.copy()
    dff.loc[:, :] = dff[dff.index > slice1]
    dff.loc[:, :] = dff[dff.index < slice2]

    return dff.dropna()

# %%
def print_adf(df: pd.DataFrame, key: str) -> None:
    series = df.loc[:, key].values

    adf_test = adfuller(series, autolag='AIC')
    p_value = adf_test[1]

    dfResults = pd.Series(adf_test[0:4], index=['ADF Test Statistic','P-Value','# Lags Used','# Observations Used'])
    #Add Critical Values
    for key,value in adf_test[4].items():
        dfResults[f'Critical Value ({key})'] = value

    print('Augmented Dickey-Fuller Test Results:')
    print(dfResults)

# %%
def print_kpss(df: pd.DataFrame, key: str) -> None:
    series = df.loc[:, key].values

    statistic, p_value, n_lags, critical_gasValue = kpss(series, nlags="auto", regression='c')
    print(f'KPSS Statistic: {statistic}')
    print(f'p-value: {p_value}')
    print(f'num lags: {n_lags}')
    print('Critial Values:')

    for key, value in critical_gasValue.items():
        print(f'   {key} : {value}')

# %% [markdown]
# # GAS series
#
# Loading and cleaning gas data.

# %%
gas: pd.DataFrame = pd.read_csv(os.path.join('data', 'avg_gas_price.csv'), header=0)
gas.rename(columns={'UnixTimeStamp': 'date', 'Value (Wei)': 'gasValue'}, inplace = True)
gas = gas[['date', 'gasValue']].dropna()
gas = transform_date_series(df=gas, date_key='date')

# %% [markdown]
# ## Original series
#
# Let's see how the series looks like.

# %%
gas_plot = filter_series(df=gas, slice1=FIRST_SLICE_DATE, slice2=datetime.today())
gas_plot['gasValue'].plot(figsize = (15, 6))
plt.show()

# %% [markdown]
# ## Splitting the series
#
# We can see there is two-stage in the series. The first stage ends around May first of 2020, from then the series changed. So let's split the series into two slices.

# %%
gas_slice1 = filter_series(df=gas, slice1=FIRST_SLICE_DATE, slice2=SECOND_SLICE_DATE)
gas_slice2 = filter_series(df=gas, slice1=SECOND_SLICE_DATE, slice2=datetime.now())

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(x=gas_slice1['gasValue'], model='additive')
fig = decomposition.plot()
plt.show()

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(x=gas_slice2['gasValue'], model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# Let's apply a log transformation to reduce higher gasValue, and also remove the weekly seasonality.

# %%
N = 7
gas_slice1['gasValue'] = gas_slice1['gasValue'] - gas_slice1['gasValue'].shift(N)
gas_slice1.dropna(inplace=True)

# %%
gas_slice1['gasValue'].plot(figsize = (15, 6))
plt.show()

# %%
gas_slice2['gasValue'] = gas_slice2['gasValue'] - gas_slice2['gasValue'].shift(N)
gas_slice2.dropna(inplace=True)

# %%
gas_slice2['gasValue'].plot(figsize = (15, 6))
plt.show()

# %% [markdown]
# ## Augmented Dickey-Fuller
#
# Let's test both series with augmented Dickey-Fuller test.
#
# Where:
#
#     * H0: The series has a unit root (non-stationary).
#     * H1: The series has no unit root (stationary).

# %%
print_adf(df=gas_slice1, key='gasValue')
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic     -8.893897e+00
# P-Value                 1.221568e-14
# # Lags Used             1.900000e+01
# # Observations Used     5.240000e+02
# Critical Value (1%)    -3.442891e+00
# Critical Value (5%)    -2.867072e+00
# Critical Value (10%)   -2.569716e+00
# dtype: float64

# %%
print_adf(df=gas_slice2, key='gasValue')
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic       -4.376326
# P-Value                   0.000327
# # Lags Used              14.000000
# # Observations Used     192.000000
# Critical Value (1%)      -3.464875
# Critical Value (5%)      -2.876714
# Critical Value (10%)     -2.574859
# dtype: float64

# %% [markdown]
# In both cases, we can reject the null hypothesis with all the confidence intervals. So, both series haven't a unit root. Hence, they are stationary series.
#
# To confirm that, we are going to perform the kpss test for cross-validation.

# %% [markdown]
# ## Kwiatkowski–Phillips–Schmidt–Shin (KPSS) Test
#
# Where:
#
#     * H0: The process is trend stationary.
#     * H1: The series has a unit root (series is not stationary).

# %%
print_kpss(df=gas_slice1, key='gasValue')
# Out:
# KPSS Statistic: 0.007239807119574772
# p-value: 0.1
# num lags: 3
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1885: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
print_kpss(df=gas_slice2, key='gasValue')
# Out:
# KPSS Statistic: 0.04364229273358933
# p-value: 0.1
# num lags: 6
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1885: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# In both cases, p-gasValue are greater than 0.05, and "KPSS Statistic" gasValue are less than the critical gasValue. So, we fail to reject H0, and because of that, we confirm that both series are stationary.

# %% [markdown]
# # Aragon activity series
#
# Let's check what about the activity series.

# %%
aragon: pd.DataFrame = pd.read_csv(os.path.join('data', 'aragon_activity.csv'), header=0)
aragon = transform_date_series(df=aragon, date_key='date')

# %%
aragon_plot = filter_series(df=aragon, slice1=FIRST_SLICE_DATE, slice2=datetime.today())
aragon_plot['actions'].plot(figsize = (15, 6))
plt.show()

# %% [markdown]
# ## Spliting the series
#
# As we previously do with the gas series, let's split the series.

# %%
aragon_slice1 = filter_series(df=aragon, slice1=FIRST_SLICE_DATE, slice2=SECOND_SLICE_DATE)
aragon_slice2 = filter_series(df=aragon, slice1=SECOND_SLICE_DATE, slice2=datetime.now())

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(x=aragon_slice1['actions'], model='additive')
fig = decomposition.plot()
plt.show()

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(x=aragon_slice2['actions'], model='additive')
fig = decomposition.plot()
plt.show()

# %%
aragon_slice1['actions'] = aragon_slice1['actions'] - aragon_slice1['actions'].shift(N)
aragon_slice1.dropna(inplace=True)

# %%
aragon_slice1['actions'].plot(figsize = (15, 6))
plt.show()

# %%
aragon_slice2['actions'] = aragon_slice2['actions'] - aragon_slice2['actions'].shift(N)
aragon_slice2.dropna(inplace=True)

# %%
aragon_slice2['actions'].plot(figsize = (15, 6))
plt.show()

# %% [markdown]
# ## Augmented Dickey-Fuller
#
# Let's test both series with augmented Dickey-Fuller test.
#
# Where:
#
#     * H0: The series has a unit root (non-stationary).
#     * H1: The series has no unit root (stationary).

# %%
print_adf(df=aragon_slice1, key='actions')
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic     -7.525046e+00
# P-Value                 3.703803e-11
# # Lags Used             1.900000e+01
# # Observations Used     5.240000e+02
# Critical Value (1%)    -3.442891e+00
# Critical Value (5%)    -2.867072e+00
# Critical Value (10%)   -2.569716e+00
# dtype: float64

# %%
print_adf(df=aragon_slice2, key='actions')
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic       -4.234551
# P-Value                   0.000576
# # Lags Used               8.000000
# # Observations Used     198.000000
# Critical Value (1%)      -3.463815
# Critical Value (5%)      -2.876251
# Critical Value (10%)     -2.574611
# dtype: float64

# %% [markdown]
# In the first series, either p-value or statistic value are lower than all the confidence and critical gasValue. In the second case, its p-value is slower than the 0.05 confidence interval. Those results suggest that we can reject H0 in favor of H1, in other words, both series are stationary.

# %% [markdown]
# ## Kwiatkowski–Phillips–Schmidt–Shin (KPSS) Test
#
# Where:
#
#     * H0: The process is trend stationary.
#     * H1: The series has a unit root (series is not stationary).

# %%
print_kpss(df=aragon_slice1, key='actions')
# Out:
# KPSS Statistic: 0.015300692721211002
# p-value: 0.1
# num lags: 9
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1885: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
print_kpss(df=aragon_slice2, key='actions')
# Out:
# KPSS Statistic: 0.05300384510620935
# p-value: 0.1
# num lags: 4
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1885: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# Both series have gasValue that suggest that we fail to reject H0. So, it is definitely a stationary series.

# %% [markdown]
# # Granger Causality Tests
#
# Where:
#
#     * H0: The second column, x2, does NOT Granger cause the time series in the first column, x1
#     * H1: x2 Granger cause x1

# %%
slice1: pd.DataFrame = pd.DataFrame(
    {'aragon_actions': aragon_slice1['actions'].tolist(),
     'gasPrice': gas_slice1['gasValue'].tolist(),
    })
    
gc_res1 = grangercausalitytests(slice1, 5)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9604  , p=0.3275  , df_denom=540, df_num=1
# ssr based chi2 test:   chi2=0.9657  , p=0.3258  , df=1
# likelihood ratio test: chi2=0.9648  , p=0.3260  , df=1
# parameter F test:         F=0.9604  , p=0.3275  , df_denom=540, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3807  , p=0.2523  , df_denom=537, df_num=2
# ssr based chi2 test:   chi2=2.7870  , p=0.2482  , df=2
# likelihood ratio test: chi2=2.7799  , p=0.2491  , df=2
# parameter F test:         F=1.3807  , p=0.2523  , df_denom=537, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9709  , p=0.4061  , df_denom=534, df_num=3
# ssr based chi2 test:   chi2=2.9510  , p=0.3992  , df=3
# likelihood ratio test: chi2=2.9429  , p=0.4005  , df=3
# parameter F test:         F=0.9709  , p=0.4061  , df_denom=534, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8010  , p=0.5249  , df_denom=531, df_num=4
# ssr based chi2 test:   chi2=3.2583  , p=0.5156  , df=4
# likelihood ratio test: chi2=3.2485  , p=0.5171  , df=4
# parameter F test:         F=0.8010  , p=0.5249  , df_denom=531, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8413  , p=0.5208  , df_denom=528, df_num=5
# ssr based chi2 test:   chi2=4.2939  , p=0.5079  , df=5
# likelihood ratio test: chi2=4.2769  , p=0.5103  , df=5
# parameter F test:         F=0.8413  , p=0.5208  , df_denom=528, df_num=5

# %%
slice2: pd.DataFrame = pd.DataFrame(
    {'aragon_actions': aragon_slice2['actions'].tolist(),
     'gasPrice': gas_slice2['gasValue'].tolist(),
    })
    
gc_res2 = grangercausalitytests(slice2, 5)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1132  , p=0.7369  , df_denom=203, df_num=1
# ssr based chi2 test:   chi2=0.1149  , p=0.7346  , df=1
# likelihood ratio test: chi2=0.1149  , p=0.7347  , df=1
# parameter F test:         F=0.1132  , p=0.7369  , df_denom=203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9796  , p=0.3773  , df_denom=200, df_num=2
# ssr based chi2 test:   chi2=2.0081  , p=0.3664  , df=2
# likelihood ratio test: chi2=1.9983  , p=0.3682  , df=2
# parameter F test:         F=0.9796  , p=0.3773  , df_denom=200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0686  , p=0.3635  , df_denom=197, df_num=3
# ssr based chi2 test:   chi2=3.3197  , p=0.3449  , df=3
# likelihood ratio test: chi2=3.2929  , p=0.3486  , df=3
# parameter F test:         F=1.0686  , p=0.3635  , df_denom=197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1821  , p=0.3200  , df_denom=194, df_num=4
# ssr based chi2 test:   chi2=4.9477  , p=0.2927  , df=4
# likelihood ratio test: chi2=4.8884  , p=0.2989  , df=4
# parameter F test:         F=1.1821  , p=0.3200  , df_denom=194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0646  , p=0.3814  , df_denom=191, df_num=5
# ssr based chi2 test:   chi2=5.6295  , p=0.3439  , df=5
# likelihood ratio test: chi2=5.5525  , p=0.3522  , df=5
# parameter F test:         F=1.0646  , p=0.3814  , df_denom=191, df_num=5

# %% [markdown]
# # VAR analysis

# %% [markdown]
# ## Slice 1

# %%
slice1: pd.DataFrame = gas_slice1.copy(deep=True)
slice1['actions'] = aragon_slice1['actions'].tolist()

# %%
model1 = VAR(slice1)
model1.select_order(15).summary()
# Out:
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results1 = model1.fit(maxlags=15, ic='aic')
results1.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 21, Dec, 2020
# Time:                     12:08:05
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    55.0319
# Nobs:                     529.000    HQIC:                   54.7273
# Log likelihood:          -15862.8    FPE:                4.81704e+23
# AIC:                      54.5313    Det(Omega_mle):     4.29849e+23
# --------------------------------------------------------------------
# Results for equation gasValue
# =================================================================================
#                    coefficient        std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const          33336513.297910  942466793.073123            0.035           0.972
# L1.gasValue           0.047687          0.044816            1.064           0.287
# L1.actions    -45653626.341167   31257205.645802           -1.461           0.144
# L2.gasValue           0.006677          0.042404            0.157           0.875
# L2.actions      6349105.896684   32714870.892926            0.194           0.846
# L3.gasValue           0.013681          0.042450            0.322           0.747
# L3.actions     -7611104.269572   32694191.920126           -0.233           0.816
# L4.gasValue           0.018152          0.042458            0.428           0.669
# L4.actions    -16014153.716153   32748672.265728           -0.489           0.625
# L5.gasValue           0.023686          0.042454            0.558           0.577
# L5.actions     27871523.526530   32793757.232713            0.850           0.395
# L6.gasValue           0.008348          0.042466            0.197           0.844
# L6.actions     12150928.351293   32814556.954338            0.370           0.711
# L7.gasValue          -0.648261          0.042462          -15.267           0.000
# L7.actions      1039709.070042   32772455.202368            0.032           0.975
# L8.gasValue           0.042008          0.051431            0.817           0.414
# L8.actions    -23755148.891633   36160237.267977           -0.657           0.511
# L9.gasValue           0.010939          0.042403            0.258           0.796
# L9.actions     16504850.901593   32941985.007381            0.501           0.616
# L10.gasValue          0.010614          0.042415            0.250           0.802
# L10.actions   -24188226.356188   32927423.870935           -0.735           0.463
# L11.gasValue          0.011300          0.042390            0.267           0.790
# L11.actions    12214338.344398   32969518.006560            0.370           0.711
# L12.gasValue          0.005330          0.042392            0.126           0.900
# L12.actions     7235999.368953   32939795.873813            0.220           0.826
# L13.gasValue          0.000311          0.042399            0.007           0.994
# L13.actions     2680361.101068   32825804.559379            0.082           0.935
# L14.gasValue         -0.327681          0.042392           -7.730           0.000
# L14.actions   -27210376.437280   32868226.826286           -0.828           0.408
# L15.gasValue          0.012265          0.044835            0.274           0.784
# L15.actions   -34837572.655527   31552924.281225           -1.104           0.270
# =================================================================================
#
# Results for equation actions
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.390315         1.319191            0.296           0.767
# L1.gasValue          0.000000         0.000000            1.286           0.198
# L1.actions           0.411158         0.043751            9.398           0.000
# L2.gasValue         -0.000000         0.000000           -1.116           0.265
# L2.actions           0.052811         0.045792            1.153           0.249
# L3.gasValue          0.000000         0.000000            0.270           0.787
# L3.actions          -0.032439         0.045763           -0.709           0.478
# L4.gasValue         -0.000000         0.000000           -0.085           0.933
# L4.actions           0.100585         0.045839            2.194           0.028
# L5.gasValue         -0.000000         0.000000           -0.821           0.412
# L5.actions           0.035086         0.045902            0.764           0.445
# L6.gasValue          0.000000         0.000000            0.325           0.745
# L6.actions          -0.061029         0.045931           -1.329           0.184
# L7.gasValue         -0.000000         0.000000           -0.414           0.679
# L7.actions          -0.626019         0.045872          -13.647           0.000
# L8.gasValue          0.000000         0.000000            0.582           0.560
# L8.actions           0.405755         0.050614            8.017           0.000
# L9.gasValue         -0.000000         0.000000           -0.575           0.566
# L9.actions           0.068674         0.046110            1.489           0.136
# L10.gasValue         0.000000         0.000000            0.696           0.486
# L10.actions         -0.065726         0.046089           -1.426           0.154
# L11.gasValue        -0.000000         0.000000           -0.500           0.617
# L11.actions          0.068313         0.046148            1.480           0.139
# L12.gasValue        -0.000000         0.000000           -0.410           0.682
# L12.actions         -0.024320         0.046107           -0.527           0.598
# L13.gasValue         0.000000         0.000000            0.137           0.891
# L13.actions         -0.052093         0.045947           -1.134           0.257
# L14.gasValue        -0.000000         0.000000           -1.356           0.175
# L14.actions         -0.267773         0.046006           -5.820           0.000
# L15.gasValue         0.000000         0.000000            0.140           0.889
# L15.actions          0.220171         0.044165            4.985           0.000
# ===============================================================================
#
# Correlation matrix of residuals
#             gasValue   actions
# gasValue    1.000000 -0.034630
# actions    -0.034630  1.000000

# %%
results1.plot_acorr()

# %% [markdown]
# ### Impulse Response

# %%
irf1 = results1.irf(20)

# %%
irf1.plot(orth=False)

# %%
irf1.cov(orth=False)
# Out:
# array([[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00]],
#
#        [[ 2.00846726e-03, -9.73545337e-14,  6.29443955e+04,
#          -3.05104414e-06],
#         [-9.73545337e-14,  3.93502908e-21, -3.05104414e-06,
#           1.23321914e-13],
#         [ 6.29443955e+04, -3.05104414e-06,  9.77012905e+14,
#          -4.73578223e+04],
#         [-3.05104414e-06,  1.23321914e-13, -4.73578223e+04,
#           1.91418315e-03]],
#
#        [[ 1.80362231e-03, -1.54607799e-13,  1.57919439e+04,
#          -1.09727280e-06],
#         [-1.54607799e-13,  4.18707492e-21, -4.86015614e-06,
#           5.72188258e-14],
#         [ 1.57919439e+04, -4.86015614e-06,  9.48504488e+14,
#          -7.96697155e+04],
#         [-1.09727280e-06,  5.72188258e-14, -7.96697155e+04,
#           2.23070039e-03]],
#
#        [[ 1.79806319e-03, -1.59607571e-13,  8.60952962e+03,
#          -7.32421317e-07],
#         [-1.59607571e-13,  4.27431968e-21, -2.44946801e-06,
#           2.81394446e-14],
#         [ 8.60952962e+03, -2.44946801e-06,  9.33379288e+14,
#          -8.64604012e+04],
#         [-7.32421317e-07,  2.81394446e-14, -8.64604012e+04,
#           2.28770949e-03]],
#
#        [[ 1.79962583e-03, -1.62941891e-13,  1.03601837e+04,
#           5.74433602e-07],
#         [-1.62941891e-13,  4.27820771e-21, -2.27996215e-06,
#           1.86986803e-14],
#         [ 1.03601837e+04, -2.27996215e-06,  9.30874029e+14,
#          -8.76281820e+04],
#         [ 5.74433602e-07,  1.86986803e-14, -8.76281820e+04,
#           2.26635536e-03]],
#
#        [[ 1.80197261e-03, -1.74939660e-13,  9.36324044e+03,
#           5.40053310e-07],
#         [-1.74939660e-13,  4.34475281e-21, -2.76285100e-06,
#           1.98747153e-14],
#         [ 9.36324044e+03, -2.76285100e-06,  9.27141203e+14,
#          -9.39238071e+04],
#         [ 5.40053310e-07,  1.98747153e-14, -9.39238071e+04,
#           2.29997159e-03]],
#
#        [[ 1.80057946e-03, -1.69844661e-13,  6.27499858e+03,
#           4.61984142e-07],
#         [-1.69844661e-13,  4.40080057e-21, -1.17991345e-06,
#           1.51045335e-14],
#         [ 6.27499858e+03, -1.17991345e-06,  9.27922456e+14,
#          -9.10404696e+04],
#         [ 4.61984142e-07,  1.51045335e-14, -9.10404696e+04,
#           2.33129667e-03]],
#
#        [[ 1.80107192e-03, -1.68310178e-13,  5.25828512e+03,
#           2.17552931e-07],
#         [-1.68310178e-13,  4.40052257e-21, -6.97052319e-07,
#           1.15068640e-14],
#         [ 5.25828512e+03, -6.97052319e-07,  9.28885112e+14,
#          -8.98551239e+04],
#         [ 2.17552931e-07,  1.15068640e-14, -8.98551239e+04,
#           2.33750057e-03]],
#
#        [[ 2.64105789e-03, -1.86716937e-13,  2.00283334e+04,
#           8.15490128e-07],
#         [-1.86716937e-13,  5.90182544e-21, -1.94107526e-06,
#           4.08341817e-14],
#         [ 2.00283334e+04, -1.94107526e-06,  1.34047479e+15,
#          -9.86344643e+04],
#         [ 8.15490128e-07,  4.08341817e-14, -9.86344643e+04,
#           3.07794236e-03]],
#
#        [[ 2.53950789e-03, -1.91843809e-13,  5.20788119e+04,
#          -9.46305087e-07],
#         [-1.91843809e-13,  5.74084664e-21, -1.98404173e-06,
#           9.00353361e-14],
#         [ 5.20788119e+04, -1.98404173e-06,  1.31638022e+15,
#          -1.03717745e+05],
#         [-9.46305087e-07,  9.00353361e-14, -1.03717745e+05,
#           3.08863277e-03]],
#
#        [[ 2.53818492e-03, -1.84217265e-13,  5.62961992e+04,
#          -2.85115756e-06],
#         [-1.84217265e-13,  5.65608985e-21, -3.13438553e-06,
#           1.17409719e-13],
#         [ 5.62961992e+04, -3.13438553e-06,  1.30793211e+15,
#          -1.01523777e+05],
#         [-2.85115756e-06,  1.17409719e-13, -1.01523777e+05,
#           3.06309201e-03]],
#
#        [[ 2.53509849e-03, -1.84500118e-13,  5.91393333e+04,
#          -5.10646033e-06],
#         [-1.84500118e-13,  5.61438125e-21, -3.41669183e-06,
#           1.33544562e-13],
#         [ 5.91393333e+04, -3.41669183e-06,  1.31004535e+15,
#          -1.03045943e+05],
#         [-5.10646033e-06,  1.33544562e-13, -1.03045943e+05,
#           3.05054012e-03]],
#
#        [[ 2.53667622e-03, -1.88880275e-13,  6.12524925e+04,
#          -7.47666507e-06],
#         [-1.88880275e-13,  5.61654175e-21, -2.72155059e-06,
#           1.39114607e-13],
#         [ 6.12524925e+04, -2.72155059e-06,  1.32190464e+15,
#          -1.05802568e+05],
#         [-7.47666507e-06,  1.39114607e-13, -1.05802568e+05,
#           3.07951331e-03]],
#
#        [[ 2.53517431e-03, -1.84632464e-13,  5.88402569e+04,
#          -7.20402581e-06],
#         [-1.84632464e-13,  5.63016877e-21, -3.03487459e-06,
#           1.37814727e-13],
#         [ 5.88402569e+04, -3.03487459e-06,  1.32113448e+15,
#          -1.04884492e+05],
#         [-7.20402581e-06,  1.37814727e-13, -1.04884492e+05,
#           3.10264733e-03]],
#
#        [[ 2.53599380e-03, -1.83002853e-13,  5.81638658e+04,
#          -7.59758994e-06],
#         [-1.83002853e-13,  5.62582968e-21, -2.29101392e-06,
#           1.38662886e-13],
#         [ 5.81638658e+04, -2.29101392e-06,  1.32244708e+15,
#          -1.03331036e+05],
#         [-7.59758994e-06,  1.38662886e-13, -1.03331036e+05,
#           3.09692897e-03]],
#
#        [[ 2.55114163e-03, -2.06478981e-13,  5.90822527e+04,
#          -9.14389891e-06],
#         [-2.06478981e-13,  5.67443351e-21, -3.85866340e-06,
#           1.38873384e-13],
#         [ 5.90822527e+04, -3.85866340e-06,  1.33335767e+15,
#          -1.15445255e+05],
#         [-9.14389891e-06,  1.38873384e-13, -1.15445255e+05,
#           3.12756420e-03]],
#
#        [[ 2.31433843e-03, -1.56947942e-13,  4.40601549e+04,
#           3.13295109e-06],
#         [-1.56947942e-13,  5.15934846e-21, -3.65208066e-06,
#           9.31819429e-14],
#         [ 4.40601549e+04, -3.65208066e-06,  1.21965044e+15,
#          -1.05294216e+05],
#         [ 3.13295109e-06,  9.31819429e-14, -1.05294216e+05,
#           2.91513483e-03]],
#
#        [[ 2.30987633e-03, -1.21261967e-13,  3.85034157e+04,
#           5.70216915e-06],
#         [-1.21261967e-13,  5.02007392e-21,  3.00513390e-06,
#           7.63456066e-14],
#         [ 3.85034157e+04,  3.00513390e-06,  1.20401983e+15,
#          -8.91329058e+04],
#         [ 5.70216915e-06,  7.63456066e-14, -8.91329058e+04,
#           2.79596553e-03]],
#
#        [[ 2.30552732e-03, -1.11428488e-13,  3.17634464e+04,
#           1.00001863e-05],
#         [-1.11428488e-13,  4.93102080e-21,  4.04024247e-06,
#           7.03373915e-14],
#         [ 3.17634464e+04,  4.04024247e-06,  1.17658512e+15,
#          -7.40982790e+04],
#         [ 1.00001863e-05,  7.03373915e-14, -7.40982790e+04,
#           2.62020332e-03]],
#
#        [[ 2.30668378e-03, -1.07719363e-13,  3.46445653e+04,
#           1.26904319e-05],
#         [-1.07719363e-13,  4.89506262e-21,  3.78482313e-06,
#           7.39575652e-14],
#         [ 3.46445653e+04,  3.78482313e-06,  1.16001344e+15,
#          -6.46965632e+04],
#         [ 1.26904319e-05,  7.39575652e-14, -6.46965632e+04,
#           2.46319264e-03]],
#
#        [[ 2.30435734e-03, -1.03747681e-13,  3.29755642e+04,
#           1.31192746e-05],
#         [-1.03747681e-13,  4.86378965e-21,  5.90049229e-06,
#           6.36502418e-14],
#         [ 3.29755642e+04,  5.90049229e-06,  1.15206471e+15,
#          -5.64390454e+04],
#         [ 1.31192746e-05,  6.36502418e-14, -5.64390454e+04,
#           2.36577649e-03]]])

# %%
irf1.plot_cum_effects(orth=False)

# %%
irf1.cum_effect_cov(orth=False)
# Out:
# array([[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00]],
#
#        [[ 2.00846726e-03, -9.73545337e-14,  6.29443955e+04,
#          -3.05104414e-06],
#         [-9.73545337e-14,  3.93502908e-21, -3.05104414e-06,
#           1.23321914e-13],
#         [ 6.29443955e+04, -3.05104414e-06,  9.77012905e+14,
#          -4.73578223e+04],
#         [-3.05104414e-06,  1.23321914e-13, -4.73578223e+04,
#           1.91418315e-03]],
#
#        [[ 4.02303401e-03, -3.14707259e-13,  9.35905703e+04,
#          -6.51428401e-06],
#         [-3.14707259e-13,  1.13627987e-20, -1.02771674e-05,
#           2.98253054e-13],
#         [ 9.35905703e+04, -1.02771674e-05,  2.10561024e+15,
#          -1.61305213e+05],
#         [-6.51428401e-06,  2.98253054e-13, -1.61305213e+05,
#           5.87310930e-03]],
#
#        [[ 6.00764607e-03, -7.33266741e-13,  1.06428399e+05,
#          -1.55253842e-05],
#         [-7.33266741e-13,  2.08919495e-20, -1.98462555e-05,
#           4.45897548e-13],
#         [ 1.06428399e+05, -1.98462555e-05,  3.24846745e+15,
#          -3.88164292e+05],
#         [-1.55253842e-05,  4.45897548e-13, -3.88164292e+05,
#           1.11928770e-02]],
#
#        [[ 8.07962419e-03, -1.25056048e-12,  1.07188380e+05,
#          -1.95945169e-05],
#         [-1.25056048e-12,  3.11810964e-20, -2.82719488e-05,
#           5.05330416e-13],
#         [ 1.07188380e+05, -2.82719488e-05,  4.42216278e+15,
#          -6.78167633e+05],
#         [-1.95945169e-05,  5.05330416e-13, -6.78167633e+05,
#           1.70222717e-02]],
#
#        [[ 1.02614945e-02, -1.98637820e-12,  1.13285932e+05,
#          -2.75608904e-05],
#         [-1.98637820e-12,  4.32268183e-20, -3.87931775e-05,
#           5.84477873e-13],
#         [ 1.13285932e+05, -3.87931775e-05,  5.66415966e+15,
#          -1.08726680e+06],
#         [-2.75608904e-05,  5.84477873e-13, -1.08726680e+06,
#           2.38181352e-02]],
#
#        [[ 1.25182065e-02, -2.76142975e-12,  1.13430056e+05,
#          -3.38280618e-05],
#         [-2.76142975e-12,  5.69629115e-20, -4.05449021e-05,
#           6.56543593e-13],
#         [ 1.13430056e+05, -4.05449021e-05,  6.93323877e+15,
#          -1.52600299e+06],
#         [-3.38280618e-05,  6.56543593e-13, -1.52600299e+06,
#           3.15263656e-02]],
#
#        [[ 1.48397104e-02, -3.44191596e-12,  1.08809614e+05,
#          -3.18616897e-05],
#         [-3.44191596e-12,  7.10959741e-20, -3.63298578e-05,
#           6.66662550e-13],
#         [ 1.08809614e+05, -3.63298578e-05,  8.23136219e+15,
#          -1.91468381e+06],
#         [-3.18616897e-05,  6.66662550e-13, -1.91468381e+06,
#           3.94707143e-02]],
#
#        [[ 1.50868057e-02, -3.80266984e-12,  8.18114970e+04,
#          -3.01967028e-05],
#         [-3.80266984e-12,  7.70677176e-20, -2.64535572e-05,
#           5.58227494e-13],
#         [ 8.18114970e+04, -2.64535572e-05,  8.47372787e+15,
#          -2.13595647e+06],
#         [-3.01967028e-05,  5.58227494e-13, -2.13595647e+06,
#           4.32791461e-02]],
#
#        [[ 1.49094901e-02, -3.97630110e-12,  5.32182101e+04,
#          -2.22869938e-05],
#         [-3.97630110e-12,  8.08406010e-20, -1.43998177e-05,
#           4.01075493e-13],
#         [ 5.32182101e+04, -1.43998177e-05,  8.66295461e+15,
#          -2.27894045e+06],
#         [-2.22869938e-05,  4.01075493e-13, -2.27894045e+06,
#           4.64902692e-02]],
#
#        [[ 1.46856862e-02, -4.00119742e-12,  4.83449082e+04,
#          -1.07500649e-05],
#         [-4.00119742e-12,  8.39780395e-20, -2.21490793e-06,
#           2.79496546e-13],
#         [ 4.83449082e+04, -2.21490793e-06,  8.81485771e+15,
#          -2.35866718e+06],
#         [-1.07500649e-05,  2.79496546e-13, -2.35866718e+06,
#           4.97559718e-02]],
#
#        [[ 1.44617624e-02, -4.00903817e-12,  4.41157324e+04,
#          -2.57135493e-06],
#         [-4.00903817e-12,  8.66500598e-20,  4.27579986e-06,
#           1.27055873e-13],
#         [ 4.41157324e+04,  4.27579986e-06,  8.95432470e+15,
#          -2.43477852e+06],
#         [-2.57135493e-06,  1.27055873e-13, -2.43477852e+06,
#           5.30050237e-02]],
#
#        [[ 1.42000480e-02, -3.83465139e-12,  5.05860304e+04,
#           2.39713471e-07],
#         [-3.83465139e-12,  8.84831674e-20,  1.81991590e-05,
#          -8.88448008e-15],
#         [ 5.05860304e+04,  1.81991590e-05,  9.11848214e+15,
#          -2.43078128e+06],
#         [ 2.39713471e-07, -8.88448008e-15, -2.43078128e+06,
#           5.60060508e-02]],
#
#        [[ 1.38844838e-02, -3.69089651e-12,  5.21785348e+04,
#           5.32415824e-06],
#         [-3.69089651e-12,  8.91669395e-20,  1.49500856e-05,
#          -1.56559268e-13],
#         [ 5.21785348e+04,  1.49500856e-05,  9.30017888e+15,
#          -2.45488618e+06],
#         [ 5.32415824e-06, -1.56559268e-13, -2.45488618e+06,
#           5.86778660e-02]],
#
#        [[ 1.35126687e-02, -3.58788455e-12,  3.93780356e+04,
#           4.20033791e-06],
#         [-3.58788455e-12,  8.93685455e-20,  1.79490750e-05,
#          -3.44755401e-13],
#         [ 3.93780356e+04,  1.79490750e-05,  9.42209654e+15,
#          -2.50618706e+06],
#         [ 4.20033791e-06, -3.44755401e-13, -2.50618706e+06,
#           6.11472342e-02]],
#
#        [[ 1.33328224e-02, -3.73100166e-12,  1.51990357e+04,
#           2.54346118e-07],
#         [-3.73100166e-12,  9.06729333e-20,  2.59879085e-05,
#          -5.82426209e-13],
#         [ 1.51990357e+04,  2.59879085e-05,  9.64932612e+15,
#          -2.69392249e+06],
#         [ 2.54346118e-07, -5.82426209e-13, -2.69392249e+06,
#           6.42431538e-02]],
#
#        [[ 1.20860041e-02, -3.88016908e-12, -6.34024249e+04,
#           2.44735313e-05],
#         [-3.88016908e-12,  8.76453010e-20,  4.07370953e-05,
#          -1.10103244e-12],
#         [-6.34024249e+04,  4.07370953e-05,  9.54939944e+15,
#          -2.97511562e+06],
#         [ 2.44735313e-05, -1.10103244e-12, -2.97511562e+06,
#           6.61795150e-02]],
#
#        [[ 1.06482545e-02, -3.92189484e-12, -1.67531228e+05,
#           6.67414167e-05],
#         [-3.92189484e-12,  8.09030394e-20,  9.21065057e-05,
#          -1.79203061e-12],
#         [-1.67531228e+05,  9.21065057e-05,  9.26516275e+15,
#          -3.26424904e+06],
#         [ 6.67414167e-05, -1.79203061e-12, -3.26424904e+06,
#           6.65875612e-02]],
#
#        [[ 9.05607099e-03, -3.77091794e-12, -2.64549849e+05,
#           1.39004575e-04],
#         [-3.77091794e-12,  7.20197581e-20,  1.60270242e-04,
#          -2.44497979e-12],
#         [-2.64549849e+05,  1.60270242e-04,  8.71344998e+15,
#          -3.44778365e+06],
#         [ 1.39004575e-04, -2.44497979e-12, -3.44778365e+06,
#           6.55689646e-02]],
#
#        [[ 7.38224261e-03, -3.61373375e-12, -3.57331447e+05,
#           2.46745576e-04],
#         [-3.61373375e-12,  6.16317806e-20,  2.22563890e-04,
#          -3.09868357e-12],
#         [-3.57331447e+05,  2.22563890e-04,  7.83376048e+15,
#          -3.58506276e+06],
#         [ 2.46745576e-04, -3.09868357e-12, -3.58506276e+06,
#           6.26498190e-02]],
#
#        [[ 5.59208900e-03, -3.35654661e-12, -4.67322833e+05,
#           3.66392218e-04],
#         [-3.35654661e-12,  5.00610219e-20,  3.09871275e-04,
#          -3.81117710e-12],
#         [-4.67322833e+05,  3.09871275e-04,  6.72934932e+15,
#          -3.62986339e+06],
#         [ 3.66392218e-04, -3.81117710e-12, -3.62986339e+06,
#           5.80534164e-02]]])

# %% [markdown]
# ## Slice 2

# %%
slice2: pd.DataFrame = gas_slice2.copy(deep=True)
slice2['actions'] = aragon_slice2['actions'].tolist()

# %%
model2 = sm.tsa.VAR(slice2)
model2.select_order(15).summary()
# Out:
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results2 = model2.fit(maxlags=9, ic='aic')
results2.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 21, Dec, 2020
# Time:                     12:10:42
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    58.2262
# Nobs:                     198.000    HQIC:                   57.8506
# Log likelihood:          -6225.82    FPE:                1.03222e+25
# AIC:                      57.5952    Det(Omega_mle):     8.59374e+24
# --------------------------------------------------------------------
# Results for equation gasValue
# ==================================================================================
#                    coefficient         std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const        1703606187.227123  5903575036.067916            0.289           0.773
# L1.gasValue           0.714825           0.073752            9.692           0.000
# L1.actions      7860962.182881   171901922.574431            0.046           0.964
# L2.gasValue          -0.331530           0.087242           -3.800           0.000
# L2.actions     -8585848.000323   171345352.844864           -0.050           0.960
# L3.gasValue           0.199031           0.082056            2.426           0.015
# L3.actions     85917159.101788   144178597.971278            0.596           0.551
# L4.gasValue          -0.049666           0.083308           -0.596           0.551
# L4.actions   -104416105.243291   144058515.522894           -0.725           0.469
# L5.gasValue          -0.048985           0.084303           -0.581           0.561
# L5.actions     25190245.191315   141619509.416968            0.178           0.859
# L6.gasValue           0.044130           0.085324            0.517           0.605
# L6.actions    -74718518.890677   143139363.173223           -0.522           0.602
# L7.gasValue          -0.533820           0.084394           -6.325           0.000
# L7.actions     63194738.573520   142441851.951485            0.444           0.657
# L8.gasValue           0.354386           0.089443            3.962           0.000
# L8.actions    110085283.727030   169300303.097254            0.650           0.516
# L9.gasValue          -0.149537           0.075234           -1.988           0.047
# L9.actions    161773528.999485   168599889.093503            0.960           0.337
# ==================================================================================
#
# Results for equation actions
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -1.228080         2.530180           -0.485           0.627
# L1.gasValue        -0.000000         0.000000           -0.444           0.657
# L1.actions          0.284584         0.073674            3.863           0.000
# L2.gasValue         0.000000         0.000000            1.463           0.144
# L2.actions          0.169340         0.073436            2.306           0.021
# L3.gasValue        -0.000000         0.000000           -0.368           0.713
# L3.actions         -0.060802         0.061793           -0.984           0.325
# L4.gasValue         0.000000         0.000000            1.818           0.069
# L4.actions          0.002551         0.061741            0.041           0.967
# L5.gasValue        -0.000000         0.000000           -1.698           0.090
# L5.actions          0.129515         0.060696            2.134           0.033
# L6.gasValue         0.000000         0.000000            1.620           0.105
# L6.actions          0.013835         0.061347            0.226           0.822
# L7.gasValue        -0.000000         0.000000           -0.832           0.405
# L7.actions         -0.560257         0.061048           -9.177           0.000
# L8.gasValue         0.000000         0.000000            0.526           0.599
# L8.actions          0.275617         0.072559            3.799           0.000
# L9.gasValue         0.000000         0.000000            1.041           0.298
# L9.actions          0.123161         0.072259            1.704           0.088
# ==============================================================================
#
# Correlation matrix of residuals
#             gasValue   actions
# gasValue    1.000000 -0.042775
# actions    -0.042775  1.000000

# %%
results2.plot_acorr()

# %% [markdown]
# ### Impulse Response

# %%
irf2 = results2.irf(20)

# %%
irf2.plot(orth=False)

# %%
irf2.cov(orth=False)
# Out:
# array([[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00]],
#
#        [[ 5.43937281e-03, -9.97191934e-14,  5.45849207e+05,
#          -1.00069704e-05],
#         [-9.97191934e-14,  9.99128431e-22, -1.00069704e-05,
#           1.00264034e-13],
#         [ 5.45849207e+05, -1.00069704e-05,  2.95502710e+16,
#          -5.41740618e+05],
#         [-1.00069704e-05,  1.00264034e-13, -5.41740618e+05,
#           5.42792651e-03]],
#
#        [[ 8.09972472e-03, -1.70992573e-13, -1.23551004e+05,
#           1.96882242e-06],
#         [-1.70992573e-13,  1.03408637e-21,  4.58078041e-07,
#          -2.79652149e-14],
#         [-1.23551004e+05,  4.58078041e-07,  3.95082332e+16,
#          -8.36269223e+05],
#         [ 1.96882242e-06, -2.79652149e-14, -8.36269223e+05,
#           5.13499978e-03]],
#
#        [[ 8.08173593e-03, -1.38784629e-13,  2.91393375e+05,
#          -1.71571826e-06],
#         [-1.38784629e-13,  1.02418622e-21,  9.68315801e-06,
#           5.64822849e-14],
#         [ 2.91393375e+05,  9.68315801e-06,  3.91694236e+16,
#          -5.93049030e+05],
#         [-1.71571826e-06,  5.64822849e-14, -5.93049030e+05,
#           4.94032504e-03]],
#
#        [[ 6.85542130e-03, -8.40539581e-14,  1.03714798e+06,
#           1.58021054e-05],
#         [-8.40539581e-14,  9.23652980e-22,  1.57899216e-05,
#           1.39021559e-13],
#         [ 1.03714798e+06,  1.57899216e-05,  3.61838927e+16,
#          -2.46780353e+05],
#         [ 1.58021054e-05,  1.39021559e-13, -2.46780353e+05,
#           4.85620978e-03]],
#
#        [[ 6.27068828e-03, -5.23271357e-14,  1.27439844e+06,
#           4.89324556e-05],
#         [-5.23271357e-14,  9.06872927e-22,  3.81177658e-05,
#           1.47259429e-13],
#         [ 1.27439844e+06,  3.81177658e-05,  3.59547766e+16,
#          -1.62536777e+04],
#         [ 4.89324556e-05,  1.47259429e-13, -1.62536777e+04,
#           4.98455653e-03]],
#
#        [[ 6.03109819e-03, -5.78771370e-14,  1.45124963e+06,
#           8.41823133e-05],
#         [-5.78771370e-14,  8.84298632e-22,  2.28829603e-05,
#           1.84257167e-13],
#         [ 1.45124963e+06,  2.28829603e-05,  3.56305880e+16,
#          -4.26374202e+04],
#         [ 8.41823133e-05,  1.84257167e-13, -4.26374202e+04,
#           5.04096484e-03]],
#
#        [[ 6.01826645e-03, -7.05663060e-14,  1.46428884e+06,
#           6.27627700e-05],
#         [-7.05663060e-14,  8.89557294e-22,  6.35493358e-05,
#           1.82097605e-13],
#         [ 1.46428884e+06,  6.35493358e-05,  3.54660503e+16,
#          -1.07112172e+05],
#         [ 6.27627700e-05,  1.82097605e-13, -1.07112172e+05,
#           5.05853562e-03]],
#
#        [[ 7.37515427e-03, -1.49854273e-13,  1.62418143e+06,
#           7.09486468e-05],
#         [-1.49854273e-13,  1.10444299e-21,  8.39289469e-05,
#           2.19354651e-13],
#         [ 1.62418143e+06,  8.39289469e-05,  4.26374239e+16,
#          -5.24208881e+05],
#         [ 7.09486468e-05,  2.19354651e-13, -5.24208881e+05,
#           6.23577102e-03]],
#
#        [[ 7.75070330e-03, -2.03553336e-13,  1.63487650e+06,
#           3.13770139e-05],
#         [-2.03553336e-13,  1.05610850e-21,  8.80000635e-05,
#           2.00440408e-13],
#         [ 1.63487650e+06,  8.80000635e-05,  4.72991173e+16,
#          -1.00418954e+06],
#         [ 3.13770139e-05,  2.00440408e-13, -1.00418954e+06,
#           6.26879506e-03]],
#
#        [[ 7.77993566e-03, -2.11725351e-13,  9.61523183e+05,
#           7.47351933e-05],
#         [-2.11725351e-13,  1.01579067e-21,  1.39575003e-04,
#           1.81061271e-13],
#         [ 9.61523183e+05,  1.39575003e-04,  4.40726042e+16,
#          -8.29836530e+05],
#         [ 7.47351933e-05,  1.81061271e-13, -8.29836530e+05,
#           5.69585505e-03]],
#
#        [[ 7.23808163e-03, -1.88629316e-13,  5.78231868e+05,
#           1.53933015e-04],
#         [-1.88629316e-13,  9.23196951e-22,  1.64086517e-04,
#           1.55992092e-13],
#         [ 5.78231868e+05,  1.64086517e-04,  4.02304229e+16,
#          -6.20501553e+05],
#         [ 1.53933015e-04,  1.55992092e-13, -6.20501553e+05,
#           5.46053890e-03]],
#
#        [[ 7.02492569e-03, -1.69773601e-13, -3.03570082e+04,
#           2.29447803e-04],
#         [-1.69773601e-13,  8.97918243e-22,  1.15334942e-04,
#           1.20024603e-13],
#         [-3.03570082e+04,  1.15334942e-04,  3.46982229e+16,
#          -6.22850301e+05],
#         [ 2.29447803e-04,  1.20024603e-13, -6.22850301e+05,
#           4.74483495e-03]],
#
#        [[ 6.98181202e-03, -1.85205723e-13, -2.88992543e+05,
#           1.96426622e-04],
#         [-1.85205723e-13,  9.02354392e-22,  5.72212252e-05,
#           8.98795856e-14],
#         [-2.88992543e+05,  5.72212252e-05,  3.07424787e+16,
#          -9.88056744e+05],
#         [ 1.96426622e-04,  8.98795856e-14, -9.88056744e+05,
#           4.29647529e-03]],
#
#        [[ 6.88419888e-03, -2.40969613e-13, -6.17953156e+05,
#           1.59820329e-04],
#         [-2.40969613e-13,  8.33829210e-22, -8.83417662e-06,
#           3.83793794e-15],
#         [-6.17953156e+05, -8.83417662e-06,  2.97438390e+16,
#          -1.11765147e+06],
#         [ 1.59820329e-04,  3.83793794e-15, -1.11765147e+06,
#           4.07796208e-03]],
#
#        [[ 7.22315173e-03, -2.35958700e-13, -6.15051510e+05,
#           1.30866817e-04],
#         [-2.35958700e-13,  9.14356577e-22, -5.30092326e-05,
#           3.73477748e-15],
#         [-6.15051510e+05, -5.30092326e-05,  3.02733564e+16,
#          -1.24646683e+06],
#         [ 1.30866817e-04,  3.73477748e-15, -1.24646683e+06,
#           4.24598336e-03]],
#
#        [[ 7.17549231e-03, -2.90507336e-13, -5.84758691e+05,
#           1.49138829e-04],
#         [-2.90507336e-13,  7.69791134e-22, -1.01354070e-04,
#          -5.11567247e-15],
#         [-5.84758691e+05, -1.01354070e-04,  3.01283281e+16,
#          -1.63242400e+06],
#         [ 1.49138829e-04, -5.11567247e-15, -1.63242400e+06,
#           3.95778998e-03]],
#
#        [[ 7.24752771e-03, -2.96808008e-13, -7.74087336e+05,
#           2.23542850e-04],
#         [-2.96808008e-13,  7.38889975e-22, -6.53056866e-05,
#           2.81164698e-15],
#         [-7.74087336e+05, -6.53056866e-05,  2.72989558e+16,
#          -1.27776928e+06],
#         [ 2.23542850e-04,  2.81164698e-15, -1.27776928e+06,
#           3.42656490e-03]],
#
#        [[ 6.04373412e-03, -2.10522750e-13, -9.25928295e+05,
#           2.43781678e-04],
#         [-2.10522750e-13,  5.91538274e-22,  2.34457904e-05,
#          -6.00292708e-14],
#         [-9.25928295e+05,  2.34457904e-05,  2.35980643e+16,
#          -7.45139117e+05],
#         [ 2.43781678e-04, -6.00292708e-14, -7.45139117e+05,
#           3.34381793e-03]],
#
#        [[ 5.61553583e-03, -1.67383024e-13, -9.27552880e+05,
#           3.11014388e-04],
#         [-1.67383024e-13,  5.77591105e-22,  2.04394108e-05,
#          -2.07753603e-14],
#         [-9.27552880e+05,  2.04394108e-05,  2.07396928e+16,
#          -2.18317826e+05],
#         [ 3.11014388e-04, -2.07753603e-14, -2.18317826e+05,
#           3.05515562e-03]],
#
#        [[ 5.61922078e-03, -1.76171964e-13, -9.36977742e+05,
#           3.09422587e-04],
#         [-1.76171964e-13,  5.81488793e-22,  3.89764872e-05,
#          -2.47096862e-14],
#         [-9.36977742e+05,  3.89764872e-05,  1.90522415e+16,
#          -1.26262343e+05],
#         [ 3.09422587e-04, -2.47096862e-14, -1.26262343e+05,
#           3.08563990e-03]]])

# %%
irf2.plot_cum_effects(orth=False)

# %%
irf2.cum_effect_cov(orth=False)
# Out:
# array([[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00]],
#
#        [[ 5.43937281e-03, -9.97191934e-14,  5.45849207e+05,
#          -1.00069704e-05],
#         [-9.97191934e-14,  9.99128431e-22, -1.00069704e-05,
#           1.00264034e-13],
#         [ 5.45849207e+05, -1.00069704e-05,  2.95502710e+16,
#          -5.41740618e+05],
#         [-1.00069704e-05,  1.00264034e-13, -5.41740618e+05,
#           5.42792651e-03]],
#
#        [[ 2.16461458e-02, -4.45008475e-13,  7.24587174e+05,
#          -1.61561317e-05],
#         [-4.45008475e-13,  2.66571102e-21, -1.76668761e-05,
#           4.18592258e-14],
#         [ 7.24587174e+05, -1.76668761e-05,  1.08748180e+17,
#          -2.24509879e+06],
#         [-1.61561317e-05,  4.18592258e-14, -2.24509879e+06,
#           1.31994538e-02]],
#
#        [[ 4.10088910e-02, -4.46879242e-13,  1.90923267e+06,
#          -9.26231246e-06],
#         [-4.46879242e-13,  4.96697080e-21,  8.25294505e-06,
#           2.92960396e-13],
#         [ 1.90923267e+06,  8.25294505e-06,  2.12176299e+17,
#          -2.21540464e+06],
#         [-9.26231246e-06,  2.92960396e-13, -2.21540464e+06,
#           2.59599047e-02]],
#
#        [[ 5.99623728e-02,  6.55678856e-14,  6.93374318e+06,
#          -4.64190605e-05],
#         [ 6.55678856e-14,  7.18850534e-21,  1.56421631e-06,
#           9.03462499e-13],
#         [ 6.93374318e+06,  1.56421631e-06,  3.28076414e+17,
#           3.55132168e+05],
#         [-4.64190605e-05,  9.03462499e-13,  3.55132168e+05,
#           3.96253005e-02]],
#
#        [[ 7.79665040e-02,  1.46861140e-12,  1.47755025e+07,
#           5.13412348e-05],
#         [ 1.46861140e-12,  9.29156816e-21,  1.28046444e-04,
#           1.79248087e-12],
#         [ 1.47755025e+07,  1.28046444e-04,  4.53592734e+17,
#           7.87559454e+06],
#         [ 5.13412348e-05,  1.79248087e-12,  7.87559454e+06,
#           5.42045022e-02]],
#
#        [[ 9.36092076e-02,  2.92060968e-12,  2.41669297e+07,
#           3.35595503e-04],
#         [ 2.92060968e-12,  1.15434560e-20,  2.65185136e-04,
#           2.99429840e-12],
#         [ 2.41669297e+07,  2.65185136e-04,  5.76256511e+17,
#           1.56304794e+07],
#         [ 3.35595503e-04,  2.99429840e-12,  1.56304794e+07,
#           7.11941970e-02]],
#
#        [[ 1.08866258e-01,  4.41189194e-12,  3.48729865e+07,
#           8.42523375e-04],
#         [ 4.41189194e-12,  1.43353596e-20,  7.24583370e-04,
#           4.35628074e-12],
#         [ 3.48729865e+07,  7.24583370e-04,  6.94677259e+17,
#           2.50632518e+07],
#         [ 8.42523375e-04,  4.35628074e-12,  2.50632518e+07,
#           9.01094437e-02]],
#
#        [[ 1.13857745e-01,  5.51749457e-12,  4.61763704e+07,
#           1.51059463e-03],
#         [ 5.51749457e-12,  1.54525981e-20,  1.39239228e-03,
#           5.87707283e-12],
#         [ 4.61763704e+07,  1.39239228e-03,  7.55901413e+17,
#           3.31584600e+07],
#         [ 1.51059463e-03,  5.87707283e-12,  3.31584600e+07,
#           1.00489642e-01]],
#
#        [[ 1.16155990e-01,  6.63317767e-12,  5.50292996e+07,
#           2.17265549e-03],
#         [ 6.63317767e-12,  1.70231868e-20,  2.29801326e-03,
#           7.23400938e-12],
#         [ 5.50292996e+07,  2.29801326e-03,  7.84292697e+17,
#           4.11829896e+07],
#         [ 2.17265549e-03,  7.23400938e-12,  4.11829896e+07,
#           1.11133108e-01]],
#
#        [[ 1.16844423e-01,  8.02488781e-12,  6.39581981e+07,
#           3.06955514e-03],
#         [ 8.02488781e-12,  1.82421136e-20,  3.78202524e-03,
#           9.05178199e-12],
#         [ 6.39581981e+07,  3.78202524e-03,  7.99489437e+17,
#           5.11157922e+07],
#         [ 3.06955514e-03,  9.05178199e-12,  5.11157922e+07,
#           1.20632491e-01]],
#
#        [[ 1.11591113e-01,  9.46029304e-12,  7.41618971e+07,
#           4.49999715e-03],
#         [ 9.46029304e-12,  1.90881266e-20,  5.49423854e-03,
#           1.13101918e-11],
#         [ 7.41618971e+07,  5.49423854e-03,  7.95255409e+17,
#           6.24324992e+07],
#         [ 4.49999715e-03,  1.13101918e-11,  6.24324992e+07,
#           1.31275539e-01]],
#
#        [[ 1.00998736e-01,  1.04448881e-11,  8.33030208e+07,
#           6.61490911e-03],
#         [ 1.04448881e-11,  1.94476499e-20,  7.47554718e-03,
#           1.39607702e-11],
#         [ 8.33030208e+07,  7.47554718e-03,  7.59686131e+17,
#           7.30241120e+07],
#         [ 6.61490911e-03,  1.39607702e-11,  7.30241120e+07,
#           1.39304993e-01]],
#
#        [[ 9.07739793e-02,  1.12224030e-11,  8.76989364e+07,
#           9.10809650e-03],
#         [ 1.12224030e-11,  1.94397151e-20,  9.60965122e-03,
#           1.63100532e-11],
#         [ 8.76989364e+07,  9.60965122e-03,  6.99061308e+17,
#           8.36563384e+07],
#         [ 9.10809650e-03,  1.63100532e-11,  8.36563384e+07,
#           1.43731703e-01]],
#
#        [[ 7.90586159e-02,  1.14983124e-11,  8.71137971e+07,
#           1.21255671e-02],
#         [ 1.14983124e-11,  1.84925750e-20,  1.17101623e-02,
#           1.83038622e-11],
#         [ 8.71137971e+07,  1.17101623e-02,  6.30303424e+17,
#           9.35254157e+07],
#         [ 1.21255671e-02,  1.83038622e-11,  9.35254157e+07,
#           1.45361526e-01]],
#
#        [[ 6.99714579e-02,  1.20542010e-11,  8.25133806e+07,
#           1.50294181e-02],
#         [ 1.20542010e-11,  1.84832854e-20,  1.36922096e-02,
#           1.99125654e-11],
#         [ 8.25133806e+07,  1.36922096e-02,  5.62114998e+17,
#           1.05108125e+08],
#         [ 1.50294181e-02,  1.99125654e-11,  1.05108125e+08,
#           1.49307570e-01]],
#
#        [[ 5.89873051e-02,  1.18938844e-11,  7.76800220e+07,
#           1.82077657e-02],
#         [ 1.18938844e-11,  1.68824016e-20,  1.54549744e-02,
#           2.17772503e-11],
#         [ 7.76800220e+07,  1.54549744e-02,  4.81811784e+17,
#           1.13712496e+08],
#         [ 1.82077657e-02,  2.17772503e-11,  1.13712496e+08,
#           1.48810704e-01]],
#
#        [[ 5.03538684e-02,  1.13379311e-11,  7.51367943e+07,
#           2.05127088e-02],
#         [ 1.13379311e-11,  1.60361178e-20,  1.68843183e-02,
#           2.34265455e-11],
#         [ 7.51367943e+07,  1.68843183e-02,  4.45540687e+17,
#           1.18533797e+08],
#         [ 2.05127088e-02,  2.34265455e-11,  1.18533797e+08,
#           1.53578891e-01]],
#
#        [[ 5.21545224e-02,  1.09240678e-11,  7.36394131e+07,
#           2.17067499e-02],
#         [ 1.09240678e-11,  1.60552462e-20,  1.81106957e-02,
#           2.46341207e-11],
#         [ 7.36394131e+07,  1.81106957e-02,  4.55371330e+17,
#           1.20916688e+08],
#         [ 2.17067499e-02,  2.46341207e-11,  1.20916688e+08,
#           1.56982627e-01]],
#
#        [[ 6.05159148e-02,  1.11264581e-11,  7.31709938e+07,
#           2.21694615e-02],
#         [ 1.11264581e-11,  1.64519027e-20,  1.93937592e-02,
#           2.54423243e-11],
#         [ 7.31709938e+07,  1.93937592e-02,  5.02232024e+17,
#           1.25363434e+08],
#         [ 2.21694615e-02,  2.54423243e-11,  1.25363434e+08,
#           1.63306988e-01]],
#
#        [[ 6.96687959e-02,  1.10196028e-11,  7.41061415e+07,
#           2.24401610e-02],
#         [ 1.10196028e-11,  1.70761579e-20,  2.06901516e-02,
#           2.61936841e-11],
#         [ 7.41061415e+07,  2.06901516e-02,  5.63569990e+17,
#           1.29025767e+08],
#         [ 2.24401610e-02,  2.61936841e-11,  1.29025767e+08,
#           1.70780512e-01]]])
