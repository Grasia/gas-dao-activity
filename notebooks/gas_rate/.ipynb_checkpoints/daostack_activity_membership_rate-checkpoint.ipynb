# %%
import os
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import pandas as pd
from datetime import datetime
from statsmodels.tsa.stattools import acf, pacf, adfuller, kpss, coint, grangercausalitytests
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
import matplotlib

# %%
FIRST_SLICE_DATE: datetime = datetime.strptime('8/4/2019', '%d/%m/%Y')
SECOND_SLICE_DATE: datetime = datetime.strptime('1/5/2020', '%d/%m/%Y')
THIRD_SLICE_DATE: datetime = datetime.strptime('30/11/2020', '%d/%m/%Y')

# %%
def transform_date_series(df: pd.DataFrame, date_key: str) -> pd.DataFrame:
    dff: pd.DataFrame = df.copy()
    dff.loc[:, date_key] = pd.to_datetime(dff.loc[:, date_key], unit='s')
    
    return dff.set_index(date_key)

# %%
def filter_series(df: pd.DataFrame, slice1: datetime, slice2: datetime) -> pd.DataFrame:
    dff: pd.DataFrame = df.copy()
    dff.loc[:, :] = dff[dff.index > slice1]
    dff.loc[:, :] = dff[dff.index < slice2]

    return dff.dropna()

# %%
def print_adf(df: pd.DataFrame, key: str) -> None:
    series = df.loc[:, key].values

    adf_test = adfuller(series, autolag='AIC')
    p_value = adf_test[1]

    dfResults = pd.Series(adf_test[0:4], index=['ADF Test Statistic','P-Value','# Lags Used','# Observations Used'])
    #Add Critical Values
    for key,value in adf_test[4].items():
        dfResults[f'Critical Value ({key})'] = value

    print('Augmented Dickey-Fuller Test Results:')
    print(dfResults)

# %%
def print_kpss(df: pd.DataFrame, key: str) -> None:
    series = df.loc[:, key].values

    statistic, p_value, n_lags, critical_gasValue = kpss(series, nlags="auto", regression='c')
    print(f'KPSS Statistic: {statistic}')
    print(f'p-value: {p_value}')
    print(f'num lags: {n_lags}')
    print('Critial Values:')

    for key, value in critical_gasValue.items():
        print(f'   {key} : {value}')

# %% [markdown]
# # GAS series
#
# Loading and cleaning gas data.

# %%
gas: pd.DataFrame = pd.read_csv(os.path.join('data', 'avg_gas_price.csv'), header=0)
gas.rename(columns={'UnixTimeStamp': 'date', 'Value (Wei)': 'gasValue'}, inplace = True)
gas = gas[['date', 'gasValue']].dropna()
gas = transform_date_series(df=gas, date_key='date')

# %% [markdown]
# ## Original series
#
# Let's see how the series looks like.

# %%
gas_plot = filter_series(df=gas, slice1=FIRST_SLICE_DATE, slice2=THIRD_SLICE_DATE)
gas_plot['gasValue'].plot(figsize = (15, 6))
plt.show()

# %% [markdown]
# ## Splitting the series
#
# We can see there is two-stage in the series. The first stage ends around May first of 2020, from then the series changed. So let's split the series into two slices.

# %%
gas_slice1 = filter_series(df=gas, slice1=FIRST_SLICE_DATE, slice2=SECOND_SLICE_DATE)
gas_slice2 = filter_series(df=gas, slice1=SECOND_SLICE_DATE, slice2=THIRD_SLICE_DATE)

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(x=gas_slice1['gasValue'], model='additive')
fig = decomposition.plot()
plt.show()

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(x=gas_slice2['gasValue'], model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# Let's apply a log transformation to reduce higher gasValue, and also remove the weekly seasonality.

# %%
N = 7
gas_slice1['gasValue'] = gas_slice1['gasValue'] - gas_slice1['gasValue'].shift(N)
gas_slice1.dropna(inplace=True)

# %%
gas_slice1['gasValue'].plot(figsize = (15, 6))
plt.show()

# %%
gas_slice2['gasValue'] = gas_slice2['gasValue'] - gas_slice2['gasValue'].shift(N)
gas_slice2.dropna(inplace=True)

# %%
gas_slice2['gasValue'].plot(figsize = (15, 6))
plt.show()

# %% [markdown]
# ## Augmented Dickey-Fuller
#
# Let's test both series with augmented Dickey-Fuller test.
#
# Where:
#
#     * H0: The series has a unit root (non-stationary).
#     * H1: The series has no unit root (stationary).

# %%
print_adf(df=gas_slice1, key='gasValue')
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic       -5.258254
# P-Value                   0.000007
# # Lags Used              16.000000
# # Observations Used     361.000000
# Critical Value (1%)      -3.448595
# Critical Value (5%)      -2.869580
# Critical Value (10%)     -2.571053
# dtype: float64

# %%
print_adf(df=gas_slice2, key='gasValue')
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic       -4.359519
# P-Value                   0.000350
# # Lags Used              14.000000
# # Observations Used     190.000000
# Critical Value (1%)      -3.465244
# Critical Value (5%)      -2.876875
# Critical Value (10%)     -2.574945
# dtype: float64

# %% [markdown]
# In both cases, we can reject the null hypothesis with all the confidence intervals. So, both series haven't a unit root. Hence, they are stationary series.
#
# To confirm that, we are going to perform the kpss test for cross-validation.

# %% [markdown]
# ## Kwiatkowski–Phillips–Schmidt–Shin (KPSS) Test
#
# Where:
#
#     * H0: The process is trend stationary.
#     * H1: The series has a unit root (series is not stationary).

# %%
print_kpss(df=gas_slice1, key='gasValue')
# Out:
# KPSS Statistic: 0.021130158096859607
# p-value: 0.1
# num lags: 7
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1885: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
print_kpss(df=gas_slice2, key='gasValue')
# Out:
# KPSS Statistic: 0.04372962613084909
# p-value: 0.1
# num lags: 6
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1885: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# In both cases, p-gasValue are greater than 0.05, and "KPSS Statistic" gasValue are less than the critical gasValue. So, we fail to reject H0, and because of that, we confirm that both series are stationary.

# %% [markdown]
# # DAOstack activity series
#
# Let's check what about the activity series.

# %%
daostack: pd.DataFrame = pd.read_csv(os.path.join('data', 'daostack_activity.csv'), header=0)
daostack = transform_date_series(df=daostack, date_key='date')

# %%
daostack_plot = filter_series(df=daostack, slice1=FIRST_SLICE_DATE, slice2=THIRD_SLICE_DATE)
daostack_plot['actions'].plot(figsize = (15, 6))
plt.show()

# %% [markdown]
# ## Spliting the series
#
# As we previously do with the gas series, let's split the series.

# %%
daostack_slice1 = filter_series(df=daostack, slice1=FIRST_SLICE_DATE, slice2=SECOND_SLICE_DATE)
daostack_slice2 = filter_series(df=daostack, slice1=SECOND_SLICE_DATE, slice2=THIRD_SLICE_DATE)

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(x=daostack_slice1['actions'], model='additive')
fig = decomposition.plot()
plt.show()

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(x=daostack_slice2['actions'], model='additive')
fig = decomposition.plot()
plt.show()

# %%
daostack_slice1['actions'] = daostack_slice1['actions'] - daostack_slice1['actions'].shift(N)
daostack_slice1.dropna(inplace=True)

# %%
daostack_slice1['actions'].plot(figsize = (15, 6))
plt.show()

# %%
daostack_slice2['actions'] = daostack_slice2['actions'] - daostack_slice2['actions'].shift(N)
daostack_slice2.dropna(inplace=True)

# %%
daostack_slice2['actions'].plot(figsize = (15, 6))
plt.show()

# %% [markdown]
# ## Augmented Dickey-Fuller
#
# Let's test both series with augmented Dickey-Fuller test.
#
# Where:
#
#     * H0: The series has a unit root (non-stationary).
#     * H1: The series has no unit root (stationary).

# %%
print_adf(df=daostack_slice1, key='actions')
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic     -7.516955e+00
# P-Value                 3.880524e-11
# # Lags Used             1.300000e+01
# # Observations Used     3.640000e+02
# Critical Value (1%)    -3.448443e+00
# Critical Value (5%)    -2.869513e+00
# Critical Value (10%)   -2.571018e+00
# dtype: float64

# %%
print_adf(df=daostack_slice2, key='actions')
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic     -7.295206e+00
# P-Value                 1.383741e-10
# # Lags Used             1.300000e+01
# # Observations Used     1.910000e+02
# Critical Value (1%)    -3.465059e+00
# Critical Value (5%)    -2.876794e+00
# Critical Value (10%)   -2.574901e+00
# dtype: float64

# %% [markdown]
# In the first series, either p-value or statistic value are lower than all the confidence and critical gasValue. In the second case, its p-value is slower than the 0.05 confidence interval. Those results suggest that we can reject H0 in favor of H1, in other words, both series are stationary.

# %% [markdown]
# ## Kwiatkowski–Phillips–Schmidt–Shin (KPSS) Test
#
# Where:
#
#     * H0: The process is trend stationary.
#     * H1: The series has a unit root (series is not stationary).

# %%
print_kpss(df=daostack_slice1, key='actions')
# Out:
# KPSS Statistic: 0.01315012322107112
# p-value: 0.1
# num lags: 6
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1885: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
print_kpss(df=daostack_slice2, key='actions')
# Out:
# KPSS Statistic: 0.03797365857968079
# p-value: 0.1
# num lags: 7
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1885: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# Both series have gasValue that suggest that we fail to reject H0. So, it is definitely a stationary series.

# %% [markdown]
# # Granger Causality Tests
#
# Where:
#
#     * H0: The second column, x2, does NOT Granger cause the time series in the first column, x1
#     * H1: x2 Granger cause x1

# %%
slice1: pd.DataFrame = pd.DataFrame(
    {'daostack_actions': daostack_slice1['actions'].tolist(),
     'gasPrice': gas_slice1['gasValue'].tolist(),
    })
    
gc_res1 = grangercausalitytests(slice1, 8)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.6838  , p=0.0176  , df_denom=374, df_num=1
# ssr based chi2 test:   chi2=5.7293  , p=0.0167  , df=1
# likelihood ratio test: chi2=5.6862  , p=0.0171  , df=1
# parameter F test:         F=5.6838  , p=0.0176  , df_denom=374, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.4093  , p=0.0128  , df_denom=371, df_num=2
# ssr based chi2 test:   chi2=8.9375  , p=0.0115  , df=2
# likelihood ratio test: chi2=8.8329  , p=0.0121  , df=2
# parameter F test:         F=4.4093  , p=0.0128  , df_denom=371, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.2824  , p=0.0210  , df_denom=368, df_num=3
# ssr based chi2 test:   chi2=10.0345 , p=0.0183  , df=3
# likelihood ratio test: chi2=9.9026  , p=0.0194  , df=3
# parameter F test:         F=3.2824  , p=0.0210  , df_denom=368, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3340  , p=0.0553  , df_denom=365, df_num=4
# ssr based chi2 test:   chi2=9.5660  , p=0.0484  , df=4
# likelihood ratio test: chi2=9.4457  , p=0.0509  , df=4
# parameter F test:         F=2.3340  , p=0.0553  , df_denom=365, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.8989  , p=0.0140  , df_denom=362, df_num=5
# ssr based chi2 test:   chi2=14.9352 , p=0.0106  , df=5
# likelihood ratio test: chi2=14.6439 , p=0.0120  , df=5
# parameter F test:         F=2.8989  , p=0.0140  , df_denom=362, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.9928  , p=0.0007  , df_denom=359, df_num=6
# ssr based chi2 test:   chi2=24.8246 , p=0.0004  , df=6
# likelihood ratio test: chi2=24.0314 , p=0.0005  , df=6
# parameter F test:         F=3.9928  , p=0.0007  , df_denom=359, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.4165  , p=0.0015  , df_denom=356, df_num=7
# ssr based chi2 test:   chi2=24.9233 , p=0.0008  , df=7
# likelihood ratio test: chi2=24.1218 , p=0.0011  , df=7
# parameter F test:         F=3.4165  , p=0.0015  , df_denom=356, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.7201  , p=0.0064  , df_denom=353, df_num=8
# ssr based chi2 test:   chi2=22.8090 , p=0.0036  , df=8
# likelihood ratio test: chi2=22.1336 , p=0.0047  , df=8
# parameter F test:         F=2.7201  , p=0.0064  , df_denom=353, df_num=8

# %% [markdown]
# With a lag of 6 (chi2 -> p=0.0004) we can reject H0, and acept that gasValue granger cause the daostack activity.

# %%
slice2: pd.DataFrame = pd.DataFrame(
    {'daostack_actions': daostack_slice2['actions'].tolist(),
     'gasPrice': gas_slice2['gasValue'].tolist(),
    })
    
gc_res2 = grangercausalitytests(slice2, 20)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4124  , p=0.5215  , df_denom=201, df_num=1
# ssr based chi2 test:   chi2=0.4185  , p=0.5177  , df=1
# likelihood ratio test: chi2=0.4181  , p=0.5179  , df=1
# parameter F test:         F=0.4124  , p=0.5215  , df_denom=201, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7787  , p=0.4604  , df_denom=198, df_num=2
# ssr based chi2 test:   chi2=1.5967  , p=0.4501  , df=2
# likelihood ratio test: chi2=1.5904  , p=0.4515  , df=2
# parameter F test:         F=0.7787  , p=0.4604  , df_denom=198, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6519  , p=0.1788  , df_denom=195, df_num=3
# ssr based chi2 test:   chi2=5.1336  , p=0.1623  , df=3
# likelihood ratio test: chi2=5.0694  , p=0.1668  , df=3
# parameter F test:         F=1.6519  , p=0.1788  , df_denom=195, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5246  , p=0.1966  , df_denom=192, df_num=4
# ssr based chi2 test:   chi2=6.3843  , p=0.1722  , df=4
# likelihood ratio test: chi2=6.2850  , p=0.1788  , df=4
# parameter F test:         F=1.5246  , p=0.1966  , df_denom=192, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4967  , p=0.1927  , df_denom=189, df_num=5
# ssr based chi2 test:   chi2=7.9190  , p=0.1608  , df=5
# likelihood ratio test: chi2=7.7663  , p=0.1696  , df=5
# parameter F test:         F=1.4967  , p=0.1927  , df_denom=189, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2681  , p=0.2740  , df_denom=186, df_num=6
# ssr based chi2 test:   chi2=8.1404  , p=0.2280  , df=6
# likelihood ratio test: chi2=7.9783  , p=0.2397  , df=6
# parameter F test:         F=1.2681  , p=0.2740  , df_denom=186, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3293  , p=0.2387  , df_denom=183, df_num=7
# ssr based chi2 test:   chi2=10.0679 , p=0.1848  , df=7
# likelihood ratio test: chi2=9.8203  , p=0.1990  , df=7
# parameter F test:         F=1.3293  , p=0.2387  , df_denom=183, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3040  , p=0.2441  , df_denom=180, df_num=8
# ssr based chi2 test:   chi2=11.4169 , p=0.1792  , df=8
# likelihood ratio test: chi2=11.0983 , p=0.1962  , df=8
# parameter F test:         F=1.3040  , p=0.2441  , df_denom=180, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3815  , p=0.1995  , df_denom=177, df_num=9
# ssr based chi2 test:   chi2=13.7685 , p=0.1308  , df=9
# likelihood ratio test: chi2=13.3064 , p=0.1492  , df=9
# parameter F test:         F=1.3815  , p=0.1995  , df_denom=177, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7726  , p=0.0687  , df_denom=174, df_num=10
# ssr based chi2 test:   chi2=19.8655 , p=0.0306  , df=10
# likelihood ratio test: chi2=18.9175 , p=0.0413  , df=10
# parameter F test:         F=1.7726  , p=0.0687  , df_denom=174, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.5953  , p=0.1039  , df_denom=171, df_num=11
# ssr based chi2 test:   chi2=19.9080 , p=0.0466  , df=11
# likelihood ratio test: chi2=18.9515 , p=0.0620  , df=11
# parameter F test:         F=1.5952  , p=0.1039  , df_denom=171, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.6158  , p=0.0913  , df_denom=168, df_num=12
# ssr based chi2 test:   chi2=22.2744 , p=0.0346  , df=12
# likelihood ratio test: chi2=21.0801 , p=0.0492  , df=12
# parameter F test:         F=1.6158  , p=0.0913  , df_denom=168, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.8175  , p=0.0441  , df_denom=165, df_num=13
# ssr based chi2 test:   chi2=27.4940 , p=0.0106  , df=13
# likelihood ratio test: chi2=25.6952 , p=0.0187  , df=13
# parameter F test:         F=1.8175  , p=0.0441  , df_denom=165, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=2.4101  , p=0.0043  , df_denom=162, df_num=14
# ssr based chi2 test:   chi2=39.7807 , p=0.0003  , df=14
# likelihood ratio test: chi2=36.1362 , p=0.0010  , df=14
# parameter F test:         F=2.4101  , p=0.0043  , df_denom=162, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=2.3097  , p=0.0053  , df_denom=159, df_num=15
# ssr based chi2 test:   chi2=41.4012 , p=0.0003  , df=15
# likelihood ratio test: chi2=37.4545 , p=0.0011  , df=15
# parameter F test:         F=2.3097  , p=0.0053  , df_denom=159, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=2.4816  , p=0.0022  , df_denom=156, df_num=16
# ssr based chi2 test:   chi2=48.1046 , p=0.0000  , df=16
# likelihood ratio test: chi2=42.8566 , p=0.0003  , df=16
# parameter F test:         F=2.4816  , p=0.0022  , df_denom=156, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=2.5352  , p=0.0014  , df_denom=153, df_num=17
# ssr based chi2 test:   chi2=52.9580 , p=0.0000  , df=17
# likelihood ratio test: chi2=46.6579 , p=0.0001  , df=17
# parameter F test:         F=2.5352  , p=0.0014  , df_denom=153, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=2.4327  , p=0.0018  , df_denom=150, df_num=18
# ssr based chi2 test:   chi2=54.5902 , p=0.0000  , df=18
# likelihood ratio test: chi2=47.8971 , p=0.0002  , df=18
# parameter F test:         F=2.4327  , p=0.0018  , df_denom=150, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=2.3354  , p=0.0025  , df_denom=147, df_num=19
# ssr based chi2 test:   chi2=56.1448 , p=0.0000  , df=19
# likelihood ratio test: chi2=49.0648 , p=0.0002  , df=19
# parameter F test:         F=2.3354  , p=0.0025  , df_denom=147, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=2.3736  , p=0.0018  , df_denom=144, df_num=20
# ssr based chi2 test:   chi2=60.9873 , p=0.0000  , df=20
# likelihood ratio test: chi2=52.7110 , p=0.0001  , df=20
# parameter F test:         F=2.3736  , p=0.0018  , df_denom=144, df_num=20

# %% [markdown]
# # VAR analysis

# %% [markdown]
# ## Slice 1

# %%
slice1: pd.DataFrame = gas_slice1.copy(deep=True)
slice1['actions'] = daostack_slice1['actions'].tolist()

# %%
model1 = VAR(slice1)
model1.select_order(15).summary()
# Out:
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results1 = model1.fit(maxlags=8, ic='bic')
results1.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 04, Jan, 2021
# Time:                     17:42:05
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    51.3424
# Nobs:                     370.000    HQIC:                   51.1257
# Log likelihood:          -10447.8    FPE:                1.38553e+22
# AIC:                      50.9828    Det(Omega_mle):     1.26648e+22
# --------------------------------------------------------------------
# Results for equation gasValue
# ================================================================================
#                   coefficient        std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const         54384628.601517  311890534.879373            0.174           0.862
# L1.gasValue          0.645625          0.052816           12.224           0.000
# L1.actions    21843670.323398   16658105.048323            1.311           0.190
# L2.gasValue         -0.321020          0.059121           -5.430           0.000
# L2.actions   -36375898.513188   14770421.862822           -2.463           0.014
# L3.gasValue          0.246939          0.061230            4.033           0.000
# L3.actions   -20311899.585309   14728952.243181           -1.379           0.168
# L4.gasValue         -0.005082          0.062475           -0.081           0.935
# L4.actions    23650477.671951   14724773.909366            1.606           0.108
# L5.gasValue          0.032161          0.062321            0.516           0.606
# L5.actions   -12570596.741825   14759971.688455           -0.852           0.394
# L6.gasValue          0.006879          0.061190            0.112           0.910
# L6.actions    20382931.059893   14746248.686099            1.382           0.167
# L7.gasValue         -0.464294          0.059588           -7.792           0.000
# L7.actions    -8121124.398965   14803681.632730           -0.549           0.583
# L8.gasValue          0.216520          0.053818            4.023           0.000
# L8.actions    15405983.722771   16306057.435088            0.945           0.345
# ================================================================================
#
# Results for equation actions
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.091374         0.991661           -0.092           0.927
# L1.gasValue         0.000000         0.000000            1.959           0.050
# L1.actions          0.317795         0.052965            6.000           0.000
# L2.gasValue         0.000000         0.000000            0.884           0.377
# L2.actions         -0.005609         0.046963           -0.119           0.905
# L3.gasValue        -0.000000         0.000000           -0.599           0.549
# L3.actions          0.078650         0.046831            1.679           0.093
# L4.gasValue        -0.000000         0.000000           -0.017           0.986
# L4.actions         -0.025937         0.046818           -0.554           0.580
# L5.gasValue        -0.000000         0.000000           -2.291           0.022
# L5.actions         -0.030854         0.046930           -0.657           0.511
# L6.gasValue         0.000000         0.000000            1.562           0.118
# L6.actions          0.063637         0.046886            1.357           0.175
# L7.gasValue         0.000000         0.000000            0.897           0.370
# L7.actions         -0.549007         0.047069          -11.664           0.000
# L8.gasValue         0.000000         0.000000            0.391           0.696
# L8.actions          0.182634         0.051845            3.523           0.000
# ==============================================================================
#
# Correlation matrix of residuals
#             gasValue   actions
# gasValue    1.000000 -0.179745
# actions    -0.179745  1.000000

# %%
results1.plot_acorr()

# %% [markdown]
# ### Impulse Response

# %%
irf1 = results1.irf(20)

# %%
irf1.plot_cum_effects(orth=True)

# %%
results1.fevd(periods=20).summary()
# Out:
# FEVD for gasValue
#       gasValue   actions
# 0     1.000000  0.000000
# 1     0.996679  0.003321
# 2     0.995095  0.004905
# 3     0.980697  0.019303
# 4     0.980977  0.019023
# 5     0.981137  0.018863
# 6     0.981070  0.018930
# 7     0.982748  0.017252
# 8     0.983175  0.016825
# 9     0.979689  0.020311
# 10    0.963603  0.036397
# 11    0.963635  0.036365
# 12    0.963775  0.036225
# 13    0.963779  0.036221
# 14    0.964268  0.035732
# 15    0.964356  0.035644
# 16    0.962763  0.037237
# 17    0.954141  0.045859
# 18    0.954171  0.045829
# 19    0.954256  0.045744
#
# FEVD for actions
#       gasValue   actions
# 0     0.032308  0.967692
# 1     0.031329  0.968671
# 2     0.046362  0.953638
# 3     0.046989  0.953011
# 4     0.047150  0.952850
# 5     0.056023  0.943977
# 6     0.056435  0.943565
# 7     0.071861  0.928139
# 8     0.071095  0.928905
# 9     0.078342  0.921658
# 10    0.077880  0.922120
# 11    0.077954  0.922046
# 12    0.084649  0.915351
# 13    0.085455  0.914545
# 14    0.095216  0.904784
# 15    0.095232  0.904768
# 16    0.099647  0.900353
# 17    0.099328  0.900672
# 18    0.099499  0.900501
# 19    0.102269  0.897731

# %%
results1.test_normality().summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results1.test_whiteness(nlags=20).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results1.test_inst_causality(causing='gasValue').summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Slice 2

# %%
slice2: pd.DataFrame = gas_slice2.copy(deep=True)
slice2['actions'] = daostack_slice2['actions'].tolist()

# %%
model2 = sm.tsa.VAR(slice2)
model2.select_order(15).summary()
# Out:
# /home/youss/Documentos/gas-dao-activity/venv/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results2 = model2.fit(maxlags=8, ic='bic')
results2.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 04, Jan, 2021
# Time:                     17:46:20
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    55.5596
# Nobs:                     197.000    HQIC:                   55.2223
# Log likelihood:          -5941.86    FPE:                7.64709e+23
# AIC:                      54.9929    Det(Omega_mle):     6.48039e+23
# --------------------------------------------------------------------
# Results for equation gasValue
# ===================================================================================
#                     coefficient         std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const         3084665697.937936  5763167693.301531            0.535           0.592
# L1.gasValue            0.685685           0.070994            9.658           0.000
# L1.actions      56149715.470231   580680654.541825            0.097           0.923
# L2.gasValue           -0.241161           0.079262           -3.043           0.002
# L2.actions    1294729196.622918   533334917.323328            2.428           0.015
# L3.gasValue            0.178255           0.081159            2.196           0.028
# L3.actions     109708900.391404   543026097.874001            0.202           0.840
# L4.gasValue           -0.008110           0.082298           -0.099           0.921
# L4.actions    -591385153.847082   537357482.514361           -1.101           0.271
# L5.gasValue           -0.078824           0.082412           -0.956           0.339
# L5.actions     226955179.900226   531603702.456889            0.427           0.669
# L6.gasValue           -0.016283           0.080681           -0.202           0.840
# L6.actions   -1123422001.414565   530108550.661262           -2.119           0.034
# L7.gasValue           -0.478319           0.078220           -6.115           0.000
# L7.actions    1013952354.185056   531018156.679701            1.909           0.056
# L8.gasValue            0.274791           0.070822            3.880           0.000
# L8.actions    1410584156.772171   576610693.695618            2.446           0.014
# ===================================================================================
#
# Results for equation actions
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.857589         0.730906           -1.173           0.241
# L1.gasValue        -0.000000         0.000000           -1.926           0.054
# L1.actions          0.275436         0.073644            3.740           0.000
# L2.gasValue         0.000000         0.000000            1.074           0.283
# L2.actions          0.124114         0.067639            1.835           0.067
# L3.gasValue         0.000000         0.000000            0.143           0.887
# L3.actions          0.102997         0.068869            1.496           0.135
# L4.gasValue         0.000000         0.000000            1.227           0.220
# L4.actions          0.048474         0.068150            0.711           0.477
# L5.gasValue         0.000000         0.000000            0.268           0.789
# L5.actions         -0.144832         0.067420           -2.148           0.032
# L6.gasValue        -0.000000         0.000000           -0.787           0.431
# L6.actions          0.111542         0.067230            1.659           0.097
# L7.gasValue        -0.000000         0.000000           -0.298           0.766
# L7.actions         -0.500847         0.067346           -7.437           0.000
# L8.gasValue        -0.000000         0.000000           -0.774           0.439
# L8.actions          0.076655         0.073128            1.048           0.295
# ==============================================================================
#
# Correlation matrix of residuals
#             gasValue   actions
# gasValue    1.000000 -0.076924
# actions    -0.076924  1.000000

# %%
results2.plot_acorr()

# %% [markdown]
# ### Impulse Response

# %%
irf2 = results2.irf(20)

# %%
irf2.plot_cum_effects(orth=True)

# %%
results2.fevd(periods=20).summary()
# Out:
# FEVD for gasValue
#       gasValue   actions
# 0     1.000000  0.000000
# 1     0.997908  0.002092
# 2     0.984682  0.015318
# 3     0.962366  0.037634
# 4     0.962406  0.037594
# 5     0.962065  0.037935
# 6     0.951308  0.048692
# 7     0.961367  0.038633
# 8     0.952044  0.047956
# 9     0.947909  0.052091
# 10    0.939470  0.060530
# 11    0.937109  0.062891
# 12    0.936201  0.063799
# 13    0.933395  0.066605
# 14    0.933190  0.066810
# 15    0.915226  0.084774
# 16    0.916267  0.083733
# 17    0.916052  0.083948
# 18    0.907409  0.092591
# 19    0.907093  0.092907
#
# FEVD for actions
#       gasValue   actions
# 0     0.006808  0.993192
# 1     0.041407  0.958593
# 2     0.075798  0.924202
# 3     0.072619  0.927381
# 4     0.072199  0.927801
# 5     0.083177  0.916823
# 6     0.090018  0.909982
# 7     0.083268  0.916732
# 8     0.118795  0.881205
# 9     0.134172  0.865828
# 10    0.133275  0.866725
# 11    0.129302  0.870698
# 12    0.129447  0.870553
# 13    0.143031  0.856969
# 14    0.143199  0.856801
# 15    0.142760  0.857240
# 16    0.142644  0.857356
# 17    0.144931  0.855069
# 18    0.144870  0.855130
# 19    0.144599  0.855401

# %%
results2.test_normality().summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results2.test_whiteness(nlags=20).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results2.test_inst_causality(causing='gasValue').summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
